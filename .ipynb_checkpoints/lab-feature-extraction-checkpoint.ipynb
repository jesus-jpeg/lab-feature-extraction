# %% [markdown]
# ![logo_ironhack_blue 7](https://user-images.githubusercontent.com/23629340/40541063-a07a0a8a-601a-11e8-91b5-2f13e4e6b441.png)
#
# # Lab | Feature extraction
#
# For this lab, we will be using the same dataset we used in the previous labs. We recommend using the same notebook since you will be reusing the same variables you previous created and used in labs.
#
# ### Instructions
#
# 1. Open the `categoricals` variable we created before.
#
# ```python
# categoricals = data.select_dtypes(np.object)
# categoricals.head()
# ```
#
# 2. Plot all the categorical variables with the proper plot. What can you see?
# 3. There might be some columns that seem to be redundant, check their values to be sure. What should we do with them?
# 4. Plot time variable. Can you extract something from it?

# %%
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

from sklearn.metrics import confusion_matrix
from sklearn.metrics import plot_confusion_matrix
from sklearn.metrics import cohen_kappa_score

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

import warnings
warnings.filterwarnings('ignore')

# %%
customer_df = pd.read_csv('files_for_lab/we_fn_use_c_marketing_customer_value_analysis.csv')
customer_df.head()
# Out:
#   Customer       State  Customer Lifetime Value Response  Coverage Education  \
# 0  BU79786  Washington              2763.519279       No     Basic  Bachelor
# 1  QZ44356     Arizona              6979.535903       No  Extended  Bachelor
# 2  AI49188      Nevada             12887.431650       No   Premium  Bachelor
# 3  WW63253  California              7645.861827       No     Basic  Bachelor
# 4  HB64268  Washington              2813.692575       No     Basic  Bachelor
#
#   Effective To Date EmploymentStatus Gender  Income  ...  \
# 0           2/24/11         Employed      F   56274  ...
# 1           1/31/11       Unemployed      F       0  ...
# 2           2/19/11         Employed      F   48767  ...
# 3           1/20/11       Unemployed      M       0  ...
# 4            2/3/11         Employed      M   43836  ...
#
#   Months Since Policy Inception Number of Open Complaints  Number of Policies  \
# ...

# %%
cols = [col_name.lower().replace(' ', '_') for col_name in customer_df]
customer_df.columns = cols
customer_df.columns
# Out:
# Index(['customer', 'state', 'customer_lifetime_value', 'response', 'coverage',
#        'education', 'effective_to_date', 'employmentstatus', 'gender',
#        'income', 'location_code', 'marital_status', 'monthly_premium_auto',
#        'months_since_last_claim', 'months_since_policy_inception',
#        'number_of_open_complaints', 'number_of_policies', 'policy_type',
#        'policy', 'renew_offer_type', 'sales_channel', 'total_claim_amount',
#        'vehicle_class', 'vehicle_size'],
#       dtype='object')

# %%
customer_df['effective_to_date'] = ["January" if x.startswith("1")==True else "February" for x in customer_df['effective_to_date']]

# %% [markdown]
# ## 1. Selecting categoricals

# %%
categoricals = customer_df.select_dtypes(np.object)
categoricals = categoricals.drop(['customer'], axis=1)
categoricals.head()
# Out:
#         state response  coverage education effective_to_date employmentstatus  \
# 0  Washington       No     Basic  Bachelor          February         Employed
# 1     Arizona       No  Extended  Bachelor           January       Unemployed
# 2      Nevada       No   Premium  Bachelor          February         Employed
# 3  California       No     Basic  Bachelor           January       Unemployed
# 4  Washington       No     Basic  Bachelor          February         Employed
#
#   gender location_code marital_status     policy_type        policy  \
# 0      F      Suburban        Married  Corporate Auto  Corporate L3
# 1      F      Suburban         Single   Personal Auto   Personal L3
# 2      F      Suburban        Married   Personal Auto   Personal L3
# 3      M      Suburban        Married  Corporate Auto  Corporate L2
# 4      M         Rural         Single   Personal Auto   Personal L1
#
#   renew_offer_type sales_channel  vehicle_class vehicle_size
# ...

# %% [markdown]
# ## 2. Plotting categoricals

# %%
for col in categoricals:
    ax = sns.countplot(customer_df[col], order=customer_df[col].value_counts(ascending=True).index )
    plt.title(f'{col} count')
    plt.show()

# %% [markdown]
# ## 3. Redundancy

# %%
customer_df.policy.value_counts()
# Out:
# Personal L3     3426
# Personal L2     2122
# Personal L1     1240
# Corporate L3    1014
# Corporate L2     595
# Corporate L1     359
# Special L2       164
# Special L3       148
# Special L1        66
# Name: policy, dtype: int64

# %%
customer_df.policy_type.value_counts()
# Out:
# Personal Auto     6788
# Corporate Auto    1968
# Special Auto       378
# Name: policy_type, dtype: int64

# %%
customer_df.renew_offer_type.value_counts()
# Out:
# Offer1    3752
# Offer2    2926
# Offer3    1432
# Offer4    1024
# Name: renew_offer_type, dtype: int64

# %% [markdown]
# I think there is some redundancy between columns **Policy** and **Policy Type**, we should drop **policy_type** as it is already indicated in column **policy**.

# %% [markdown]
# ## 4. Plotting Dates

# %% [markdown]
# We gonna do two cases, first one with number of clients by date, and second one with average claim amount by date.

# %%
df = pd.read_csv('files_for_lab/we_fn_use_c_marketing_customer_value_analysis.csv')
df1 = df[["Effective To Date"]]
df2 = df[["Effective To Date","Total Claim Amount"]]
time = df1.groupby(df1.columns.tolist(),as_index=False).size()
tca = df2.groupby(df2["Effective To Date"])['Total Claim Amount'].mean().reset_index()
time.head()
# Out:
#   Effective To Date  size
# 0            1/1/11   148
# 1           1/10/11   195
# 2           1/11/11   166
# 3           1/12/11   126
# 4           1/13/11   145

# %%
tca = pd.DataFrame(tca)
tca.head()
# Out:
#   Effective To Date  Total Claim Amount
# 0            1/1/11          455.949957
# 1           1/10/11          440.885685
# 2           1/11/11          407.115501
# 3           1/12/11          371.416538
# 4           1/13/11          458.188947

# %% [markdown]
# ### Number of clients vs Date chart

# %%
import datetime
import random
import matplotlib.dates as mdates
time["Effective To Date"] = pd.to_datetime(time["Effective To Date"], errors='coerce')
# sort DataFrame by date
time = time.sort_values(by=["Effective To Date"])

x_values = time["Effective To Date"]
y_values = time["size"]

# plot data
plt.plot_date(x_values, y_values, linestyle="solid", marker="")

# add labels and title
plt.xlabel('Date')
plt.ylabel('Size')
plt.title('Size vs. Date')

# rotate x-axis label
plt.xticks(rotation=45)

# show plot
plt.tight_layout()
plt.show()

# %% [markdown]
# **Another way of doing it**

# %%
# create timeseries plot
time.plot(x="Effective To Date", y="size")
plt.xlabel("Date",  size = 10)
plt.ylabel("Count", size = 10)
plt.title("Count of Effective to Date", size = 15)
# Out:
# Text(0.5, 1.0, 'Count of Effective to Date')

# %% [markdown]
# ### Avg Claim Amount vs Date

# %%
import datetime
import random
import matplotlib.dates as mdates
tca["Effective To Date"] = pd.to_datetime(tca["Effective To Date"], errors='coerce')
# sort DataFrame by date
tca = tca.sort_values(by=["Effective To Date"])

x_values = tca["Effective To Date"]
y_values = tca["Total Claim Amount"]

# plot data
plt.plot_date(x_values, y_values, linestyle="solid", marker="")

# rotate x-axis label
plt.xticks(rotation=45)

plt.xlabel('Date')
plt.ylabel('Avg Claim Amount')
plt.title('Avg Claim Amount vs. Date')

# plot
plt.tight_layout()
plt.show()

plt.show()

# %% [markdown]
# ### Merging both charts

# %%
import pandas as pd
import matplotlib.pyplot as plt

# convert date column to datetime type
time["Effective To Date"] = pd.to_datetime(time["Effective To Date"], errors='coerce')
tca["Effective To Date"] = pd.to_datetime(tca["Effective To Date"], errors='coerce')

# sort DataFrame by date
time = time.sort_values(by=["Effective To Date"])
tca = tca.sort_values(by=["Effective To Date"])

# create figure and axes
fig, ax = plt.subplots()

# extract x and y values for chart 1
x_values_1 = time["Effective To Date"]
y_values_1 = time["size"]

# extract x and y values for chart 2
x_values_2 = tca["Effective To Date"]
y_values_2 = tca["Total Claim Amount"]


# plot chart 1
ax.plot_date(x_values_1, y_values_1, linestyle="solid", marker="", label="Quantity of customers")

# plot chart 2
ax.plot_date(x_values_2, y_values_2, linestyle="solid", marker="", label="Avg Claim Amount")

# add labels and title
ax.set_xlabel('Date')
ax.set_ylabel('Measurement (units)')
ax.set_title('Size and Avg Claim Amount vs. Date')

# rotate x-axis label
plt.xticks(rotation=45)

# add legend
ax.legend()

# show plot
plt.tight_layout()
plt.show()

# %% [markdown]
# Just trying new things I guess...

# %% [markdown]
# #### <div class="alert alert-block alert-info">In summary, we could see the amount of policies that are effective to each date in the first chart.</div>
# #### <div class="alert alert-block alert-warning">Then I tried to represent the Average Claim Amount for every Date.</div></div>
# #### <div class="alert alert-block alert-success">And finally, I plot them together just to dig in how to do it :)</div>
# #### <div class="alert alert-block alert-danger">Just trying all colors</div>
